# %%
import mysql.connector
from mysql.connector import Error
try:
    # Membuat koneksi ke database MySQL
    connection = mysql.connector.connect(
        host='localhost',          # Nama host atau IP server MySQL
        database='rumah_sakit',  # Nama database yang akan digunakan
        user='root',               # Username MySQL (sesuaikan)
        password=''        # Password MySQL (sesuaikan)
    )
    if connection.is_connected():
        print("Koneksi ke MySQL berhasil!")       
        # Membuat cursor untuk eksekusi query
        cursor = connection.cursor()
        
        # Menjalankan query SQL
        cursor.execute("SELECT DATABASE();")
        record = cursor.fetchone()
        print(f"Anda terhubung ke database: {record}")
        


        # print("==================================")
        # print("Menambahkan inputan dari User")

        # # Meminta input dari pengguna
        # nama_pasien = input("Masukkan nama pasien: ")
        # tanggal_lahir = input("Masukkan tanggal lahir (YYYY-MM-DD): ")
        # jenis_kelamin = input("Masukkan jenis kelamin (L/P): ")
        # alamat = input("Masukkan alamat: ")

        # # Menyisipkan data ke dalam tabel pasien
        # sql = "INSERT INTO tbl_pasien (nama, tgl_lahir, jenis_kelamin, alamat) VALUES (%s, %s, %s, %s)"
        # val = (nama_pasien, tanggal_lahir, jenis_kelamin, alamat)
        # cursor.execute(sql, val)

        # # Menyimpan perubahan ke database
        # connection.commit()
        # print("Data pasien berhasil ditambahkan!")




        # print("==================================")
        # print("Menambahkan UPDATE user berdasarkan user ingin mengupdate apa")

        # if connection.is_connected():
        #     print("Koneksi ke database berhasil!")

        #     # Membuat cursor untuk menjalankan query
        #     cursor = connection.cursor()

        #     # Meminta input ID pasien
        #     id_pasien = input("Masukkan ID pasien yang ingin diubah: ")

        #     # Meminta pengguna memilih data yang ingin diubah
        #     print("Pilih data yang ingin diubah:")
        #     print("1. Nama")
        #     print("2. Tanggal Lahir")
        #     print("3. Jenis Kelamin")
        #     print("4. Alamat")
        #     pilihan = input("Masukkan pilihan Anda (1-4): ")

        #     if pilihan == '1':
        #         nama_baru = input("Masukkan nama baru: ")
        #         sql = "UPDATE tbl_pasien SET nama = %s WHERE id_pasien = %s"
        #         val = (nama_baru, id_pasien)
        #     elif pilihan == '2':
        #         tanggal_lahir_baru = input("Masukkan tanggal lahir baru (YYYY-MM-DD): ")
        #         sql = "UPDATE tbl_pasien SET tgl_lahir = %s WHERE id_pasien = %s"
        #         val = (tanggal_lahir_baru, id_pasien)
        #     elif pilihan == '3':
        #         jenis_kelamin_baru = input("Masukkan jenis kelamin baru (L/P): ")
        #         sql = "UPDATE tbl_pasien SET jenis_kelamin = %s WHERE id_pasien = %s"
        #         val = (jenis_kelamin_baru, id_pasien)
        #     elif pilihan == '4':
        #         alamat_baru = input("Masukkan alamat baru: ")
        #         sql = "UPDATE tbl_pasien SET alamat = %s WHERE id_pasien = %s"
        #         val = (alamat_baru, id_pasien)
            

        #     # Melakukan update data
        #     cursor.execute(sql, val)
        #     connection.commit()
        #     print("Data pasien berhasil diperbarui!")




        # print("==================================")
        # print("Menghapus data pasien berdasarkan id_pasien yang diberikan oleh user")
        # # Meminta input ID pasien
        # id_pasien = input("Masukkan ID pasien yang ingin dihapus: ")

        # # Konfirmasi penghapusan
        # konfirmasi = input(f"Apakah Anda yakin ingin menghapus data pasien dengan ID {id_pasien}? (ya/tidak): ")
        # if konfirmasi.lower() != 'ya':
        #     print("Penghapusan dibatalkan.")
            

        #     # Query untuk menghapus data pasien
        #     sql = "DELETE FROM tbl_pasien WHERE id_pasien = %s"
        #     val = (id_pasien,)
        #     cursor.execute(sql, val)

        #     # Menyimpan perubahan ke database
        #     connection.commit()
        #     print("Data pasien berhasil dihapus!")

        # else:
        #     print("Koneksi ke database gagal.")



        print("==================================")
        print("Menampilkan Seluruh Data")
        
        # Fungsi untuk menampilkan semua data pasien
        def tampilkan_pasien():
            # ... (kode yang sama seperti pada jawaban sebelumnya)

        # Fungsi untuk menambahkan pasien (sama seperti jawaban sebelumnya)
            def tambah_pasien():
            # ... (kode yang sama seperti pada jawaban sebelumnya)

        # Fungsi untuk memperbarui pasien (sama seperti jawaban sebelumnya)
                def update_pasien():
            # ... (kode yang sama seperti pada jawaban sebelumnya)

        # Fungsi untuk menghapus pasien (sama seperti jawaban sebelumnya)
                    def hapus_pasien():
            # ... (kode yang sama seperti pada jawaban sebelumnya)

                        # Fungsi utama
                        def main():
                            while True:
                                print("\nMenu:")
                                print("1. Tampilkan semua data pasien")
                                print("2. Tambah data pasien baru")
                                print("3. Update data pasien")
                                print("4. Hapus data pasien")
                                print("5. Keluar")

                                pilihan = input("Masukkan pilihan Anda: ")

                                if pilihan == '1':
                                    tampilkan_pasien()
                                elif pilihan == '2':
                                    tambah_pasien()
                                    tampilkan_pasien()  # Tampilkan data setelah penambahan
                                elif pilihan == '3':
                                    update_pasien()
                                    tampilkan_pasien()  # Tampilkan data setelah pembaruan
                                elif pilihan == '4':
                                    hapus_pasien()
                                    tampilkan_pasien()  # Tampilkan data setelah penghapusan
                                elif pilihan == '5':
                                    break
                                else:
                                    print("Pilihan tidak valid.")

                        if __name__ == "__main__":
                            main()




        # # Query untuk menampilkan semua data dari tabel tbl_pasien
        # cursor.execute("SELECT * FROM tbl_pasien")

        # # Mengambil semua hasil query
        # myresult = cursor.fetchall()

        # # Menampilkan hasil dalam bentuk tabel
        # for x in myresult:
        #     print (x)



except Error as e:
    print(f"Error saat terhubung ke MySQL: {e}")

finally:
    if connection.is_connected():
        cursor.close()
        connection.close()
        print("Koneksi ke MySQL ditutup.")
# Out:
# Koneksi ke MySQL berhasil!
# Anda terhubung ke database: ('rumah_sakit',)
# ...
# Menghapus data pasien berdasarkan id_pasien yang diberikan oleh user
# Penghapusan dibatalkan.
# Data pasien berhasil dihapus!
# Koneksi ke MySQL ditutup.
