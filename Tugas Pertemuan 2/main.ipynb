# %%
import numpy as np
import pandas as pd
import matplotlib.ticker as ticker  #Library untuk membuat grfik
import matplotlib.pyplot as plt
import seaborn as sns    


sns.set()
import warnings
warnings.filterwarnings('ignore')


print("\n=================================================")
print("INI ADALAH DATA DARI SAMPLE SUPERSTORE DATA CSV")
print("=================================================\n")
#Read SampelSuperstore data
df = pd.read_csv('SampleSuperstore.csv') #Read the dataset
df
# Out:
# ...
# INI ADALAH DATA DARI SAMPLE SUPERSTORE DATA CSV
# ...
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9988  Standard Class  Corporate  United States           Athens     Georgia
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
#
# ...

# %%
print("\n=================================================")
print("INI ADALAH DATA SAMPLE SUPERSTORE DATA CSV YNAG SUDAH DI HITUNG DESKRIPSI STATISTIK DARI DATA NUMAERIK")
print("=================================================\n")
#  Menghitung statistik deskriptif dari data numerik dalam DataFrame
data = df.describe(include="all")
data
# Out:
# ...
# INI ADALAH DATA SAMPLE SUPERSTORE DATA CSV YNAG SUDAH DI HITUNG DESKRIPSI STATISTIK DARI DATA NUMAERIK
# ...
#              Ship Mode   Segment        Country           City       State  \
# count             9993      9993           9993           9993        9993
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5190           9993            915        2000
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# ...

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MEMBUAT DAN MENAMPILKAN HISTOGRAM DARI SEMUA KOLOM NUMERIK DALAM DATAFRAME")
print("=================================================\n")

# Fungsi ini digunakan untuk membuat dan menampilkan histogram dari semua kolom numerik dalam dataframe
print(df.hist(bins=10, figsize=(18, 10)))
# Out:
# ...
# FUNGSI INI DIGUNAKAN UNTUK MEMBUAT DAN MENAMPILKAN HISTOGRAM DARI SEMUA KOLOM NUMERIK DALAM DATAFRAME
# ...
#
# [[<Axes: title={'center': 'Postal Code'}>
#   <Axes: title={'center': 'Sales'}>]
#  [<Axes: title={'center': 'Quantity'}>
#   <Axes: title={'center': 'Discount'}>]
#  [<Axes: title={'center': 'Profit'}> <Axes: >]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

print("\n=================================================")
print("FUNGSI INI DIPERUNTUKKAN UNTUK MENGUBAH DATA DARI DATAFRAME MENJADI DATA GRAFIK")
print("=================================================\n")
# Fungsi untuk mengubah data menjadi data grafik warna


plt.figure(figsize=(8, 6))
sns.heatmap(df, annot=True, cmap='coolwarm')
plt.title('Matriks Korelasi')
plt.show()
# Out:
# ...
# FUNGSI INI DIPERUNTUKKAN UNTUK MENGUBAH DATA DARI DATAFRAME MENJADI DATA GRAFIK
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 12
#       8 # Fungsi untuk mengubah data menjadi data grafik warna
#      11 plt.figure(figsize=(8, 6))
# ---> 12 sns.heatmap(df, annot=True, cmap='coolwarm')
#      13 plt.title('Matriks Korelasi')
#      14 plt.show()
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# ...

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MEMBUAT MATRIKS PLOT YANG MENUNJUKKAN HUBUNGAN ANTARA SEMUA PASANGAN VARIABEL NUMERIK DALAM DATAFRAME")
print("=================================================\n")

# Fungsi ini digunaakan untuk membuat matriks plot
# Menunjukkan hubungan antara semua pasangan variabel numerik dalam dataframe
sns.pairplot(df, hue='Ship Mode')

# %%
print("\n=================================================")
print("FUNGSI INI DIPERUNTUKKAN UNTUK MENGUBAH DATA DARI DATAFRAME MENJADI SHIP MODE BENTUK DIAGRAM BAR")
print("=================================================\n")

# fungsi ini digunakan untuk membuat diagram batang(bar plot)
# Menunjukkan frekuensi atau jumlah kemunculan setiap kategori dalam kolom 'Ship Mode'
# Ship mode dagram batang
sns.countplot(x='Ship Mode', data=df, palette='tab10') #sns.countplot untuk membuat diagram batang dari seaborn
# Out:
# ...
# FUNGSI INI DIPERUNTUKKAN UNTUK MENGUBAH DATA DARI DATAFRAME MENJADI SHIP MODE BENTUK DIAGRAM BAR
# ...
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_1956\3018349591.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Ship Mode', data=df, palette='tab10')
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %%
print("\n=================================================")
print("FUNGSI INI DIPERUNTUKKAN UNTUK MENGUBAH DATA DARI DATAFRAME MENJADI SHIP MODE BENTUK DIAGRAM BAR")
print("=================================================\n")

# Fungsi ini digunaan untuk mengelompokkan data berdasarkan nilai unik dalam kolom 'Ship Mode'ArithmeticError
# Data akan dibagi menjadi beberapa kelompok yang masing-masing mewakili satu jenis 'Ship Mode'

# Fungsi keseluruhan adalah digunakan untuk menghitung rata-rata penjualan, keuntungan dan diskon untuk setiap jenis mode pengiriman (ship mode) dalam dataset
df_shipmode = df.groupby(['Ship Mode']) [['Sales', 'Profit', 'Discount']].mean() #fungsi mean disini sebagai menghitung rata-rata dari kolom yang telah ditentukan untuk setiap kelompok
df_shipmode
# Out:
# ...
# FUNGSI INI DIPERUNTUKKAN UNTUK MENGUBAH DATA DARI DATAFRAME MENJADI SHIP MODE BENTUK DIAGRAM BAR
# ...
#                      Sales     Profit  Discount
# Ship Mode
# First Class     228.497024  31.839948  0.164610
# Same Day        236.396179  29.266591  0.152394
# Second Class    236.085602  29.513214  0.138966
# Standard Class  227.583067  27.494770  0.160023

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MEMBUAT DIAGRAM PAI (PIE CHART) YANG MENAMPILKAN FISTRIBUSI DATA DALAM DATAFRAME")
print("=================================================\n")

# 
colors_4 = ['magenta', 'yellow', 'orange', 'red']
colors_3 = ['green', 'blue', 'cyan']

df_shipmode.plot.pie(subplots=True, figsize=(20, 10), labels = df_shipmode.index, autopct = '%1.1f%%', explode = (0.01, 0.01, 0.01, 0.01), colors=colors_4)
plt.show()
# Out:
# ...
# FUNGSI INI DIGUNAKAN UNTUK MEMBUAT DIAGRAM PAI (PIE CHART) YANG MENAMPILKAN FISTRIBUSI DATA DALAM DATAFRAME
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MEMBUAT PERBANDINGAN NILAI DALAM DIAGRAM BATANG")
print("=================================================\n")

# Fungsi ini digunakan untuk membuat visualisasi data dalam bentuk diagram batang 
# Secara spesifik : untuk membandingkan nilai 'Profit' dan 'Sales' untuk setiap kategori dalam dataFra

df_shipmode.sort_values('Profit')[['Profit', 'Sales']].plot(kind='bar', figsize=(10, 7))
# Out:
# ...
# FUNGSI INI DIGUNAKAN UNTUK MEMBUAT PERBANDINGAN NILAI DALAM DIAGRAM BATANG
# ...
# <Axes: xlabel='Ship Mode'>

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MENGHITUNG JUMLAH TOTAL DARI SETIAP KOLOM DALAM DATAFRAME")
print("=================================================\n")

# Fungsi ini digunakan untuk melakukan analisis
# Menghitung jumlah total dari setiap kolom
df_shipmode.sum(axis=0)
df_shipmode
# Out:
# ...
# FUNGSI INI DIGUNAKAN UNTUK MENGHITUNG JUMLAH TOTAL DARI SETIAP KOLOM DALAM DATAFRAME
# ...
#                      Sales     Profit  Discount     Sales%    Profit%
# Ship Mode
# Standard Class  227.583067  27.494770  0.160023  24.510831  23.280923
# Same Day        236.396179  29.266591  0.152394  25.460008  24.781195
# Second Class    236.085602  29.513214  0.138966  25.426559  24.990020
# First Class     228.497024  31.839948  0.164610  24.609265  26.960159

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MENGHITUNG PRESENTASE 'SALES' DAN 'PROFIT' BERDASARKAN TOTAL TERTENTU")
print("=================================================\n")

# fungsi df_shipmode : menghitung presentase 'sales' dan 'profit'

# Membagi setiap nilai dalam kolom 'Sales' dengan 9.285. Hasilnya disimpan dalam kolom baru bernama 'Sales%'.
df_shipmode['Sales%'] = df_shipmode['Sales']/9.285

#Membagi setiap nilai dalam kolom 'Profit' dengan 1.181. Hasilnya disimpan dalam kolom baru bernama 'Profit%'.
df_shipmode['Profit%'] = df_shipmode['Profit']/1.181

# Mengurutkan DataFrame df_shipmode berdasarkan nilai kolom 'Profit%' secara menaik.
df_shipmode.sort_values('Profit%')
# Out:
# ...
# FUNGSI INI DIGUNAKAN UNTUK MENGHITUNG JUMLAH TOTAL DARI SETIAP KOLOM DALAM DATAFRAME
# ...
#                      Sales     Profit  Discount     Sales%    Profit%
# Ship Mode
# Standard Class  227.583067  27.494770  0.160023  24.510831  23.280923
# Same Day        236.396179  29.266591  0.152394  25.460008  24.781195
# Second Class    236.085602  29.513214  0.138966  25.426559  24.990020
# First Class     228.497024  31.839948  0.164610  24.609265  26.960159

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MEMBUAT PAIR PLOT ATAU PLOT PASANGAN")
print("=================================================\n")

# igunakan untuk membuat pair plot atau plot pasangan
sns.pairplot(df, hue='Segment')
# Out:
# ...
# FUNGSI INI DIGUNAKAN UNTUK MEMBUAT PAIR PLOT ATAU PLOT PASANGAN
# ...

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MEMBUAT VISUALISASI DISTRIBUSI FREKUENSI KATEGORIKAL")
print("=================================================\n")

# untuk membuat count plot atau plot hitungan.
# memvisualisasikan distribusi frekuensi kategorikal dari suatu variabel dalam dataset
sns.countplot(x='Segment', data = df, palette='tab10')
# Out:
# ...
# FUNGSI INI DIGUNAKAN UNTUK MEMBUAT VISUALISASI DISTRIBUSI FREKUENSI KATEGORIKAL
# ...
# <Axes: xlabel='Segment', ylabel='count'>

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MEMBUAT DIAGRAM PIE DARI NILAI RATA-RATA KOLOM SALES, PROFIT DAN DISCOUNT")
print("=================================================\n")


df_segment = df.groupby(['Segment'])[['Sales', 'Profit', 'Discount']].mean() #Mengelompokkan DataFrame df berdasarkan kolom 'Segment'.
#[['Sales', 'Profit', 'Discount']]: Memilih hanya kolom 'Sales', 'Profit', dan 'Discount' dari setiap kelompok.
df_segment.plot.pie(subplots=True, figsize=(20,10), labels=df_segment.index, autopct='%1.1f%%', colors=colors_3)
# Out:
# ...
# FUNGSI INI DIGUNAKAN UNTUK MEMBUAT VISUALISASI DISTRIBUSI FREKUENSI KATEGORIKAL
# ...
# array([<Axes: ylabel='Sales'>, <Axes: ylabel='Profit'>,
#        <Axes: ylabel='Discount'>], dtype=object)

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MEMBUAT VISUALISASI DATA DALAM BENTUK DAGRAM BATANG 9BAR CHART)")
print("=================================================\n")

df_segment.sort_values('Profit')[['Profit', 'Sales']].plot(kind='bar')
# Out:
# <Axes: xlabel='Segment'>

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MENJUMLAHKAN TOTAL PENJUALAN, PROFIT DAN SALES DARI KESELURUHAN")
print("=================================================\n")

# digunakan untuk mendapatkan total dari setiap kolom dalam DataFrame
df_segment.sum(axis=0)
df_segment
# Out:
#                   Sales     Profit  Discount
# Segment
# Consumer     223.729901  25.827796  0.158171
# Corporate    233.823300  30.456667  0.158228
# Home Office  240.972041  33.818664  0.147128

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MENGHITUNG PRESENTASE DARI KOLOM 'SALES' DAN 'PROFIT' DALAM DATAFRAME")
print("=================================================\n")

df_segment['Sales%'] = df_segment['Sales']/6.985 # MENAMBAHKAN KOLOM BARU BERNAMA 'SALES%', SETIAP NILAI DALAM KOLOM 'SALES' DIBAGI DENGAN 6.985
df_segment['Profit%'] = df_segment['Profit']/0.9011

df_segment.sort_values('Profit')
df_segment
# Out:
#                   Sales     Profit  Discount     Sales%    Profit%
# Segment
# Consumer     223.729901  25.827796  0.158171  32.030050  28.662519
# Corporate    233.823300  30.456667  0.158228  33.475061  33.799431
# Home Office  240.972041  33.818664  0.147128  34.498503  37.530423

# %%
print("\n=================================================")
print("FUNGSI INI DIGUNAKAN UNTUK MENGHITUNG PRESENTASE DARI KOLOM 'SALES' DAN 'PROFIT' DALAM DATAFRAME")
print("=================================================\n")


plt.figure(figsize=(18, 10))
sns.countplot(df['State'])
plt.xticks(rotation=90)
# Out:
# ...
# FUNGSI INI DIGUNAKAN UNTUK MENGHITUNG PRESENTASE DARI KOLOM 'SALES' DAN 'PROFIT' DALAM DATAFRAME
# ...
# (array([   0.,  250.,  500.,  750., 1000., 1250., 1500., 1750., 2000.,
#         2250.]),
#  [Text(0.0, 0, '0'),
#   Text(250.0, 0, '250'),
#   Text(500.0, 0, '500'),
#   Text(750.0, 0, '750'),
#   Text(1000.0, 0, '1000'),
#   Text(1250.0, 0, '1250'),
#   Text(1500.0, 0, '1500'),
#   Text(1750.0, 0, '1750'),
#   Text(2000.0, 0, '2000'),
#   Text(2250.0, 0, '2250')])

# %%
df_state = df.groupby(['State'])[['Sales', 'Profit', 'Discount']].mean()

df_state1 = df_state.sort_values('Profit')
df_state2 = df_state.sort_values('Sales')
df_state2['Sales'].plot(kind='bar', figsize=(15,7))
# Out:
# <Axes: xlabel='State'>

# %%
df_state1['Profit'].plot(kind='bar', figsize=(15,7))
# Out:
# <Axes: xlabel='State'>

# %%
# sorted by profits
df_state.sort_values('Profit')[['Profit', 'Sales']].plot(kind='bar', figsize=(18,8))
# Out:
# <Axes: xlabel='State'>

# %%
#sorted by sales
df_state.sort_values('Sales')[['Profit', 'Sales']].plot(kind='bar', figsize=(18,8))
# Out:
# <Axes: xlabel='State'>

# %%
df_state.sum(axis=0)
# Out:
# Sales       13545.400821
# Profit       2648.326892
# Discount        4.076661
# dtype: float64

# %%
df_state['Sales%'] = df_state['Sales']/135.454
df_state['Profit%'] = df_state['Profit']/26.483
df_state.sort_values('Profit%')
# Out:
#                             Sales      Profit  Discount     Sales%   Profit%
# State
# Ohio                   166.861697  -36.186304  0.324947   1.231870 -1.366397
# Colorado               176.418231  -35.867351  0.316484   1.302422 -1.354354
# North Carolina         223.305880  -30.083985  0.283534   1.648574 -1.135973
# Tennessee              167.551219  -29.189583  0.291257   1.236960 -1.102201
# Pennsylvania           198.487077  -26.507598  0.328620   1.465347 -1.000929
# Texas                  172.779742  -26.121174  0.370193   1.275560 -0.986337
# Illinois               162.939230  -25.625787  0.390041   1.202912 -0.967632
# Arizona                157.508933  -15.303235  0.303571   1.162822 -0.577851
# Oregon                 140.573790   -9.600569  0.288710   1.037797 -0.362518
# Florida                233.612815   -8.875461  0.299347   1.724665 -0.335138
# New Mexico             129.284378   31.273408  0.059459   0.954452  1.180886
# ...

# %%
sns.countplot(df['Region'], palette='tab10')
# Out:
# <Axes: xlabel='count', ylabel='Region'>

# %%
df_region2 = df.groupby(['Region'])[['Sales', 'Profit']].mean()
df_region2
# Out:
#               Sales     Profit
# Region
# Central  215.772661  17.092709
# East     238.336110  32.135808
# South    241.803645  28.857673
# West     226.488028  33.836821

# %%
df_region2.plot.pie(subplots=True, figsize=(15,7), autopct='%1.1f%%', label=df_region2.index.values)
# Out:
# array([<Axes: ylabel='Sales'>, <Axes: ylabel='Profit'>], dtype=object)

# %%
df_region2.sum(axis=0)
# Out:
# Sales     922.400443
# Profit    111.923010
# dtype: float64

# %%
df_region2['Sales%'] = df_region2['Sales']/9.224
df_region2['Profit%'] = df_region2['Profit']/1.119

df_region2.sort_values('Profit')
# Out:
#               Sales     Profit     Sales%    Profit%
# Region
# Central  215.772661  17.092709  23.392526  15.274986
# South    241.803645  28.857673  26.214619  25.788805
# East     238.336110  32.135808  25.838694  28.718327
# West     226.488028  33.836821  24.554209  30.238446

# %%
plt.figure(figsize=(15,7))
sns.countplot(df['Sub-Category'])
plt.xticks(rotation=90)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200., 1400., 1600.]),
#  [Text(0.0, 0, '0'),
#   Text(200.0, 0, '200'),
#   Text(400.0, 0, '400'),
#   Text(600.0, 0, '600'),
#   Text(800.0, 0, '800'),
#   Text(1000.0, 0, '1000'),
#   Text(1200.0, 0, '1200'),
#   Text(1400.0, 0, '1400'),
#   Text(1600.0, 0, '1600')])

# %%
df_subcat = df.groupby(['Sub-Category'])[['Sales', 'Profit']].mean()
df_subcat
# Out:
#                     Sales      Profit
# Sub-Category
# Accessories    215.974604   54.111788
# Appliances     230.729034   38.849586
# Art             34.068834    8.200737
# Binders        133.560560   19.843574
# Bookcases      503.859633  -15.230509
# Chairs         532.332420   43.095894
# Copiers       2198.941618  817.909190
# Envelopes       64.867724   27.418019
# Fasteners       13.936774    4.375660
# Furnishings     95.825668   13.645918
# Labels          34.303055   15.236962
# Machines      1645.553313   29.432669
# Paper           57.284092   24.856620
# Phones         371.211534   50.073938
# Storage        264.590553   25.152277
# Supplies       245.650200   -6.258418
# Tables         648.794771  -55.565771

# %%
plt.figure(figsize=(15,18))
plt.pie(df_subcat['Sales'], labels = df_subcat.index, autopct='%1.1f%%')
plt.show()

# %%
df_subcat.sort_values('Profit')[['Profit', 'Sales']].plot(kind='bar', figsize=(15,10))
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
df_subcat.sum(axis=0)
# Out:
# Sales     7291.484388
# Profit    1095.148131
# dtype: float64

# %%
df_subcat['Sales%'] = df_subcat['Sales']/72.915
df_subcat['Profit%'] = df_subcat['Profit']/10.952

df_subcat.sort_values('Sales')
# Out:
#                     Sales      Profit     Sales%    Profit%
# Sub-Category
# Fasteners       13.936774    4.375660   0.191137   0.399531
# Art             34.068834    8.200737   0.467240   0.748789
# Labels          34.303055   15.236962   0.470453   1.391249
# Paper           57.284092   24.856620   0.785628   2.269596
# Envelopes       64.867724   27.418019   0.889635   2.503471
# Furnishings     95.825668   13.645918   1.314211   1.245975
# Binders        133.560560   19.843574   1.831730   1.811868
# Accessories    215.974604   54.111788   2.962005   4.940813
# Appliances     230.729034   38.849586   3.164356   3.547259
# Supplies       245.650200   -6.258418   3.368994  -0.571441
# Storage        264.590553   25.152277   3.628753   2.296592
# Phones         371.211534   50.073938   5.091017   4.572127
# Bookcases      503.859633  -15.230509   6.910233  -1.390660
# Chairs         532.332420   43.095894   7.300726   3.934979
# ...
